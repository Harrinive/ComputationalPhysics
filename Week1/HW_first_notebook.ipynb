# %% [markdown]
# # My first jupyter notenook!
# In this notebook, I will try some learned methods on jupyter by using VS code editer. Besides, I will take some notes about how to finish a project.
#
# ## First, write some Markdown code to take note.
# - `**` to bold the letters. **Example**
# - `|` , `:` and `-` to make a table
# ### Example table
# |Col 1|Col 2|Col 3|
# |::|::|::|
# |1|2|3|
# |4|5|6
#
# ## Second, new a cell (`A`) and write some python code.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0.1, 10, 20)
y = np.log(x)
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Finaly, run the code with `Shift+Enter`.
